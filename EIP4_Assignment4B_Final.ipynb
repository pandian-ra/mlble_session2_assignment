# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
# from keras.layers import Activation, Flatten, Dense, 

import numpy as np
import os

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
subtract_pixel_mean = True
# n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
# if version == 1:
#     depth = n * 6 + 2
# elif version == 2:
depth = 20 

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print(cifar10.load_data())

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# ((array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8), array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)), (array([[[[158, 112,  49],
#          [159, 111,  47],
#          [165, 116,  51],
#          ...,
#          [137,  95,  36],
#          [126,  91,  36],
#          [116,  85,  33]],
#
#         [[152, 112,  51],
#          [151, 110,  40],
#          [159, 114,  45],
#          ...,
#          [136,  95,  31],
#          [125,  91,  32],
#          [119,  88,  34]],
#
#         [[151, 110,  47],
#          [151, 109,  33],
#          [158, 111,  36],
#          ...,
#          [139,  98,  34],
#          [130,  95,  34],
#          [120,  89,  33]],
#
#         ...,
#
#         [[ 68, 124, 177],
#          [ 42, 100, 148],
#          [ 31,  88, 137],
#          ...,
#          [ 38,  97, 146],
#          [ 13,  64, 108],
#          [ 40,  85, 127]],
#
#         [[ 61, 116, 168],
#          [ 49, 102, 148],
#          [ 35,  85, 132],
#          ...,
#          [ 26,  82, 130],
#          [ 29,  82, 126],
#          [ 20,  64, 107]],
#
#         [[ 54, 107, 160],
#          [ 56, 105, 149],
#          [ 45,  89, 132],
#          ...,
#          [ 24,  77, 124],
#          [ 34,  84, 129],
#          [ 21,  67, 110]]],
#
#
#        [[[235, 235, 235],
#          [231, 231, 231],
#          [232, 232, 232],
#          ...,
#          [233, 233, 233],
#          [233, 233, 233],
#          [232, 232, 232]],
#
#         [[238, 238, 238],
#          [235, 235, 235],
#          [235, 235, 235],
#          ...,
#          [236, 236, 236],
#          [236, 236, 236],
#          [235, 235, 235]],
#
#         [[237, 237, 237],
#          [234, 234, 234],
#          [234, 234, 234],
#          ...,
#          [235, 235, 235],
#          [235, 235, 235],
#          [234, 234, 234]],
#
#         ...,
#
#         [[ 87,  99,  89],
#          [ 43,  51,  37],
#          [ 19,  23,  11],
#          ...,
#          [169, 184, 179],
#          [182, 197, 193],
#          [188, 202, 201]],
#
#         [[ 82,  96,  82],
#          [ 46,  57,  36],
#          [ 36,  44,  22],
#          ...,
#          [174, 189, 183],
#          [185, 200, 196],
#          [187, 202, 200]],
#
#         [[ 85, 101,  83],
#          [ 62,  75,  48],
#          [ 58,  67,  38],
#          ...,
#          [168, 183, 178],
#          [180, 195, 191],
#          [186, 200, 199]]],
#
#
#        [[[158, 190, 222],
#          [158, 187, 218],
#          [139, 166, 194],
#          ...,
#          [228, 231, 234],
#          [237, 239, 243],
#          [238, 241, 246]],
#
#         [[170, 200, 229],
#          [172, 199, 226],
#          [151, 176, 201],
#          ...,
#          [232, 232, 236],
#          [246, 246, 250],
#          [246, 247, 251]],
#
#         [[174, 201, 225],
#          [176, 200, 222],
#          [157, 179, 199],
#          ...,
#          [230, 229, 232],
#          [250, 249, 251],
#          [245, 244, 247]],
#
#         ...,
#
#         [[ 31,  40,  45],
#          [ 30,  39,  44],
#          [ 26,  35,  40],
#          ...,
#          [ 37,  40,  46],
#          [  9,  13,  14],
#          [  4,   7,   5]],
#
#         [[ 23,  34,  39],
#          [ 27,  38,  43],
#          [ 25,  36,  41],
#          ...,
#          [ 19,  20,  24],
#          [  4,   6,   3],
#          [  5,   7,   3]],
#
#         [[ 28,  41,  47],
#          [ 30,  43,  50],
#          [ 32,  45,  52],
#          ...,
#          [  5,   6,   8],
#          [  4,   5,   3],
#          [  7,   8,   7]]],
#
#
#        ...,
#
#
#        [[[ 20,  15,  12],
#          [ 19,  14,  11],
#          [ 15,  14,  11],
#          ...,
#          [ 10,   9,   7],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         [[ 21,  16,  13],
#          [ 20,  16,  13],
#          [ 18,  17,  12],
#          ...,
#          [ 10,   9,   7],
#          [ 10,   9,   7],
#          [ 12,  11,   9]],
#
#         [[ 21,  16,  13],
#          [ 21,  17,  12],
#          [ 20,  18,  11],
#          ...,
#          [ 12,  11,   9],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         ...,
#
#         [[ 33,  25,  13],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 28,  25,  52],
#          [ 29,  25,  58],
#          [ 23,  20,  42]],
#
#         [[ 33,  25,  14],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 27,  24,  52],
#          [ 27,  24,  56],
#          [ 25,  22,  47]],
#
#         [[ 31,  23,  12],
#          [ 32,  24,  13],
#          [ 33,  25,  14],
#          ...,
#          [ 24,  23,  50],
#          [ 26,  23,  53],
#          [ 25,  20,  47]]],
#
#
#        [[[ 25,  40,  12],
#          [ 15,  36,   3],
#          [ 23,  41,  18],
#          ...,
#          [ 61,  82,  78],
#          [ 92, 113, 112],
#          [ 75,  89,  92]],
#
#         [[ 12,  25,   6],
#          [ 20,  37,   7],
#          [ 24,  36,  15],
#          ...,
#          [115, 134, 138],
#          [149, 168, 177],
#          [104, 117, 131]],
#
#         [[ 12,  25,  11],
#          [ 15,  29,   6],
#          [ 34,  40,  24],
#          ...,
#          [154, 172, 182],
#          [157, 175, 192],
#          [116, 129, 151]],
#
#         ...,
#
#         [[100, 129,  81],
#          [103, 132,  84],
#          [104, 134,  86],
#          ...,
#          [ 97, 128,  84],
#          [ 98, 126,  84],
#          [ 91, 121,  79]],
#
#         [[103, 132,  83],
#          [104, 131,  83],
#          [107, 135,  87],
#          ...,
#          [101, 132,  87],
#          [ 99, 127,  84],
#          [ 92, 121,  79]],
#
#         [[ 95, 126,  78],
#          [ 95, 123,  76],
#          [101, 128,  81],
#          ...,
#          [ 93, 124,  80],
#          [ 95, 123,  81],
#          [ 92, 120,  80]]],
#
#
#        [[[ 73,  78,  75],
#          [ 98, 103, 113],
#          [ 99, 106, 114],
#          ...,
#          [135, 150, 152],
#          [135, 149, 154],
#          [203, 215, 223]],
#
#         [[ 69,  73,  70],
#          [ 84,  89,  97],
#          [ 68,  75,  81],
#          ...,
#          [ 85,  95,  89],
#          [ 71,  82,  80],
#          [120, 133, 135]],
#
#         [[ 69,  73,  70],
#          [ 90,  95, 100],
#          [ 62,  71,  74],
#          ...,
#          [ 74,  81,  70],
#          [ 53,  62,  54],
#          [ 62,  74,  69]],
#
#         ...,
#
#         [[123, 128,  96],
#          [132, 132, 102],
#          [129, 128, 100],
#          ...,
#          [108, 107,  88],
#          [ 62,  60,  55],
#          [ 27,  27,  28]],
#
#         [[115, 121,  91],
#          [123, 124,  95],
#          [129, 126,  99],
#          ...,
#          [115, 116,  94],
#          [ 66,  65,  59],
#          [ 27,  27,  27]],
#
#         [[116, 120,  90],
#          [121, 122,  94],
#          [129, 128, 101],
#          ...,
#          [116, 115,  94],
#          [ 68,  65,  58],
#          [ 27,  26,  26]]]], dtype=uint8), array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]])))
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 10:
        lr *= 1e-1
    elif epoch > 25:
        lr *= 1e-2
    elif epoch > 35:
        lr *= 1e-1
    
    # if epoch > 40:
    #     lr *= 0.5e-3
    # elif epoch > 30:
    #     lr *= 1e-3
    # elif epoch > 20:
    #     lr *= 1e-2
    # elif epoch > 10:
    #     lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=64,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 64
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    # if (depth - 2) % 9 != 0:
    #     raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 64
    # num_res_blocks = int((depth - 2) / 9)
    num_res_blocks = int((depth - 2) / 9)
    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = Dense(256)(x)
    # x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    

    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 32, 32, 64)   1792        input_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 32, 32, 64)   256         conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 32, 32, 64)   0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 32, 32, 64)   4160        activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 32, 32, 64)   256         conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 32, 32, 64)   0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 32, 32, 64)   36928       activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 32, 32, 64)   256         conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 32, 32, 64)   0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 32, 32, 256)  16640       activation_191[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 32, 32, 256)  16640       activation_193[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 32, 32, 256)  0           conv2d_225[0][0]
#                                                                  conv2d_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 32, 32, 256)  1024        add_61[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 32, 32, 256)  0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 32, 32, 64)   16448       activation_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 32, 32, 64)   256         conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 32, 32, 64)   0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 32, 32, 64)   36928       activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 32, 32, 64)   256         conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 32, 32, 64)   0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 32, 32, 256)  16640       activation_196[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 32, 32, 256)  0           add_61[0][0]
#                                                                  conv2d_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 32, 32, 256)  1024        add_62[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 32, 32, 256)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 16, 16, 256)  65792       activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 16, 16, 256)  1024        conv2d_229[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 16, 16, 256)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 16, 16, 256)  590080      activation_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 16, 16, 256)  1024        conv2d_230[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 16, 16, 256)  0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 16, 16, 512)  131584      add_62[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 16, 16, 512)  131584      activation_199[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 16, 16, 512)  0           conv2d_232[0][0]
#                                                                  conv2d_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 16, 16, 512)  2048        add_63[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 16, 16, 512)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 16, 16, 256)  131328      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 16, 16, 256)  1024        conv2d_233[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 16, 16, 256)  0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 16, 16, 256)  590080      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 16, 16, 256)  1024        conv2d_234[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 16, 16, 256)  0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 16, 16, 512)  131584      activation_202[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 16, 16, 512)  0           add_63[0][0]
#                                                                  conv2d_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 16, 16, 512)  2048        add_64[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 16, 16, 512)  0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 8, 8, 512)    262656      activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 8, 8, 512)    2048        conv2d_236[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 8, 8, 512)    0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 8, 8, 512)    2359808     activation_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 8, 8, 512)    2048        conv2d_237[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 8, 8, 512)    0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 8, 8, 1024)   525312      add_64[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 8, 8, 1024)   525312      activation_205[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 8, 8, 1024)   0           conv2d_239[0][0]
#                                                                  conv2d_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 8, 8, 1024)   4096        add_65[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 8, 8, 1024)   0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 8, 8, 512)    524800      activation_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 8, 8, 512)    2048        conv2d_240[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 8, 8, 512)    0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 8, 8, 512)    2359808     activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 8, 8, 512)    2048        conv2d_241[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 8, 8, 512)    0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 8, 8, 1024)   525312      activation_208[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 8, 8, 1024)   0           add_65[0][0]
#                                                                  conv2d_242[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 8, 8, 256)    262400      add_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 8, 8, 256)    1024        dense_21[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 8, 8, 256)    0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, 1, 1, 256)    0           activation_209[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 256)          0           average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 10)           2570        flatten_11[0][0]
# ==================================================================================================
# Total params: 9,291,018
# Trainable params: 9,278,602
# Non-trainable params: 12,416
# __________________________________________________________________________________________________
# ResNet20v2

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 161ms/step - loss: 0.8230 - acc: 0.8227 - val_loss: 1.3103 - val_acc: 0.6959
#
# Epoch 00001: val_acc improved from 0.69410 to 0.69590, saving model to /content/saved_models/cifar10_ResNet20v2_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.7929 - acc: 0.8303 - val_loss: 0.9871 - val_acc: 0.7667
#
# Epoch 00002: val_acc improved from 0.69590 to 0.76670, saving model to /content/saved_models/cifar10_ResNet20v2_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.7731 - acc: 0.8349 - val_loss: 1.3731 - val_acc: 0.6731
#
# Epoch 00003: val_acc did not improve from 0.76670
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.7493 - acc: 0.8436 - val_loss: 1.4073 - val_acc: 0.6692
#
# Epoch 00004: val_acc did not improve from 0.76670
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.7332 - acc: 0.8469 - val_loss: 1.2401 - val_acc: 0.6846
#
# Epoch 00005: val_acc did not improve from 0.76670
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.7105 - acc: 0.8522 - val_loss: 0.9528 - val_acc: 0.7775
#
# Epoch 00006: val_acc improved from 0.76670 to 0.77750, saving model to /content/saved_models/cifar10_ResNet20v2_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.7063 - acc: 0.8524 - val_loss: 0.9319 - val_acc: 0.7934
#
# Epoch 00007: val_acc improved from 0.77750 to 0.79340, saving model to /content/saved_models/cifar10_ResNet20v2_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.6931 - acc: 0.8555 - val_loss: 1.1806 - val_acc: 0.7370
#
# Epoch 00008: val_acc did not improve from 0.79340
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.6744 - acc: 0.8624 - val_loss: 1.0358 - val_acc: 0.7594
#
# Epoch 00009: val_acc did not improve from 0.79340
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.6636 - acc: 0.8666 - val_loss: 0.8837 - val_acc: 0.8039
#
# Epoch 00010: val_acc improved from 0.79340 to 0.80390, saving model to /content/saved_models/cifar10_ResNet20v2_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.6539 - acc: 0.8675 - val_loss: 0.8796 - val_acc: 0.8066
#
# Epoch 00011: val_acc improved from 0.80390 to 0.80660, saving model to /content/saved_models/cifar10_ResNet20v2_model.011.h5
# Epoch 12/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.5263 - acc: 0.9094 - val_loss: 0.6027 - val_acc: 0.8841
#
# Epoch 00012: val_acc improved from 0.80660 to 0.88410, saving model to /content/saved_models/cifar10_ResNet20v2_model.012.h5
# Epoch 13/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 161ms/step - loss: 0.4830 - acc: 0.9224 - val_loss: 0.5811 - val_acc: 0.8845
#
# Epoch 00013: val_acc improved from 0.88410 to 0.88450, saving model to /content/saved_models/cifar10_ResNet20v2_model.013.h5
# Epoch 14/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.4599 - acc: 0.9271 - val_loss: 0.5722 - val_acc: 0.8879
#
# Epoch 00014: val_acc improved from 0.88450 to 0.88790, saving model to /content/saved_models/cifar10_ResNet20v2_model.014.h5
# Epoch 15/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 161ms/step - loss: 0.4421 - acc: 0.9311 - val_loss: 0.5526 - val_acc: 0.8941
#
# Epoch 00015: val_acc improved from 0.88790 to 0.89410, saving model to /content/saved_models/cifar10_ResNet20v2_model.015.h5
# Epoch 16/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.4251 - acc: 0.9354 - val_loss: 0.5620 - val_acc: 0.8890
#
# Epoch 00016: val_acc did not improve from 0.89410
# Epoch 17/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.4113 - acc: 0.9379 - val_loss: 0.5601 - val_acc: 0.8893
#
# Epoch 00017: val_acc did not improve from 0.89410
# Epoch 18/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3986 - acc: 0.9397 - val_loss: 0.5677 - val_acc: 0.8872
#
# Epoch 00018: val_acc did not improve from 0.89410
# Epoch 19/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3876 - acc: 0.9438 - val_loss: 0.5441 - val_acc: 0.8960
#
# Epoch 00019: val_acc improved from 0.89410 to 0.89600, saving model to /content/saved_models/cifar10_ResNet20v2_model.019.h5
# Epoch 20/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 161ms/step - loss: 0.3751 - acc: 0.9469 - val_loss: 0.5382 - val_acc: 0.8948
#
# Epoch 00020: val_acc did not improve from 0.89600
# Epoch 21/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3634 - acc: 0.9497 - val_loss: 0.5505 - val_acc: 0.8931
#
# Epoch 00021: val_acc did not improve from 0.89600
# Epoch 22/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3558 - acc: 0.9493 - val_loss: 0.5443 - val_acc: 0.8961
#
# Epoch 00022: val_acc improved from 0.89600 to 0.89610, saving model to /content/saved_models/cifar10_ResNet20v2_model.022.h5
# Epoch 23/50
# Learning rate:  0.0001
# 391/391 [==============================] - 63s 160ms/step - loss: 0.3467 - acc: 0.9527 - val_loss: 0.5498 - val_acc: 0.8937
#
# Epoch 00023: val_acc did not improve from 0.89610
# Epoch 24/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3393 - acc: 0.9543 - val_loss: 0.5426 - val_acc: 0.8940
#
# Epoch 00024: val_acc did not improve from 0.89610
# Epoch 25/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3351 - acc: 0.9552 - val_loss: 0.5730 - val_acc: 0.8878
#
# Epoch 00025: val_acc did not improve from 0.89610
# Epoch 26/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3260 - acc: 0.9568 - val_loss: 0.5436 - val_acc: 0.8934
#
# Epoch 00026: val_acc did not improve from 0.89610
# Epoch 27/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.3203 - acc: 0.9576 - val_loss: 0.5211 - val_acc: 0.9001
#
# Epoch 00027: val_acc improved from 0.89610 to 0.90010, saving model to /content/saved_models/cifar10_ResNet20v2_model.027.h5
# Epoch 28/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.3088 - acc: 0.9618 - val_loss: 0.5604 - val_acc: 0.8905
#
# Epoch 00028: val_acc did not improve from 0.90010
# Epoch 29/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.3018 - acc: 0.9635 - val_loss: 0.5359 - val_acc: 0.8999
#
# Epoch 00029: val_acc did not improve from 0.90010
# Epoch 30/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.2992 - acc: 0.9634 - val_loss: 0.6201 - val_acc: 0.8802
#
# Epoch 00030: val_acc did not improve from 0.90010
# Epoch 31/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2924 - acc: 0.9651 - val_loss: 0.5305 - val_acc: 0.9007
#
# Epoch 00031: val_acc improved from 0.90010 to 0.90070, saving model to /content/saved_models/cifar10_ResNet20v2_model.031.h5
# Epoch 32/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2882 - acc: 0.9662 - val_loss: 0.5798 - val_acc: 0.8889
#
# Epoch 00032: val_acc did not improve from 0.90070
# Epoch 33/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2810 - acc: 0.9681 - val_loss: 0.5655 - val_acc: 0.8927
#
# Epoch 00033: val_acc did not improve from 0.90070
# Epoch 34/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2785 - acc: 0.9684 - val_loss: 0.5395 - val_acc: 0.8991
#
# Epoch 00034: val_acc did not improve from 0.90070
# Epoch 35/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2746 - acc: 0.9689 - val_loss: 0.5675 - val_acc: 0.8967
#
# Epoch 00035: val_acc did not improve from 0.90070
# Epoch 36/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2689 - acc: 0.9700 - val_loss: 0.5466 - val_acc: 0.8994
#
# Epoch 00036: val_acc did not improve from 0.90070
# Epoch 37/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.2646 - acc: 0.9726 - val_loss: 0.5451 - val_acc: 0.8986
#
# Epoch 00037: val_acc did not improve from 0.90070
# Epoch 38/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.2621 - acc: 0.9714 - val_loss: 0.5901 - val_acc: 0.8907
#
# Epoch 00038: val_acc did not improve from 0.90070
# Epoch 39/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.2565 - acc: 0.9732 - val_loss: 0.5916 - val_acc: 0.8911
#
# Epoch 00039: val_acc did not improve from 0.90070
# Epoch 40/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2542 - acc: 0.9733 - val_loss: 0.5950 - val_acc: 0.8893
#
# Epoch 00040: val_acc did not improve from 0.90070
# Epoch 41/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2488 - acc: 0.9759 - val_loss: 0.5632 - val_acc: 0.8952
#
# Epoch 00041: val_acc did not improve from 0.90070
# Epoch 42/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2444 - acc: 0.9767 - val_loss: 0.6213 - val_acc: 0.8871
#
# Epoch 00042: val_acc did not improve from 0.90070
# Epoch 43/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2421 - acc: 0.9771 - val_loss: 0.5461 - val_acc: 0.9040
#
# Epoch 00043: val_acc improved from 0.90070 to 0.90400, saving model to /content/saved_models/cifar10_ResNet20v2_model.043.h5
# Epoch 44/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2400 - acc: 0.9775 - val_loss: 0.5627 - val_acc: 0.8991
#
# Epoch 00044: val_acc did not improve from 0.90400
# Epoch 45/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2355 - acc: 0.9788 - val_loss: 0.5687 - val_acc: 0.8937
#
# Epoch 00045: val_acc did not improve from 0.90400
# Epoch 46/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2368 - acc: 0.9775 - val_loss: 0.5981 - val_acc: 0.8871
#
# Epoch 00046: val_acc did not improve from 0.90400
# Epoch 47/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2304 - acc: 0.9800 - val_loss: 0.5914 - val_acc: 0.8927
#
# Epoch 00047: val_acc did not improve from 0.90400
# Epoch 48/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 158ms/step - loss: 0.2299 - acc: 0.9802 - val_loss: 0.5656 - val_acc: 0.8992
#
# Epoch 00048: val_acc did not improve from 0.90400
# Epoch 49/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 159ms/step - loss: 0.2279 - acc: 0.9787 - val_loss: 0.6199 - val_acc: 0.8830
#
# Epoch 00049: val_acc did not improve from 0.90400
# Epoch 50/50
# Learning rate:  0.0001
# 391/391 [==============================] - 62s 160ms/step - loss: 0.2262 - acc: 0.9802 - val_loss: 0.6084 - val_acc: 0.8913
#
# Epoch 00050: val_acc did not improve from 0.90400
# 10000/10000 [==============================] - 6s 576us/step

# %%
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from google.colab.patches import cv2_imshow
from keras.preprocessing import image
import cv2
from skimage import io

# %%
def GradCam(input_img):
    input_img = io.imread(input_img)
    input_img = cv2.resize(input_img, dsize=(32, 32), interpolation=cv2.INTER_CUBIC)
    x = image.img_to_array(input_img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)   

    preds = model.predict(x)
    class_idx = np.argmax(preds[0])
    print(class_idx)
    class_output = model.output[:, class_idx]
    last_conv_layer = model.get_layer("conv2d_242") 

    from keras import backend as K
    grads = K.gradients(class_output, last_conv_layer.output)[0]
    print(grads.shape)
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
    print(pooled_grads.shape)
    iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

    pooled_grads_value, conv_layer_output_value = iterate([x])

    for i in range(512):
        conv_layer_output_value[:, :, i] *= pooled_grads_value[i]    

    heatmap = np.mean(conv_layer_output_value, axis = -1)
    print(conv_layer_output_value.shape)
    print(heatmap.shape)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap)

    heatmap = cv2.resize(heatmap, (input_img.shape[1], input_img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = cv2.addWeighted(input_img, 0.5, heatmap, 0.5, 0)

    return input_img, superimposed_img

# %%
img1 = GradCam("http://style24x7.com/wp-content/uploads/2019/10/Baby-Turtle-Wallpapers-Background-HD-Image-1.jpg")
img2 = GradCam("http://style24x7.com/wp-content/uploads/2019/10/Baby-Turtle-Wallpapers-Background-HD-Image-45.jpg")
img3 = GradCam("http://style24x7.com/wp-content/uploads/2019/10/Baby-Turtle-Wallpapers-Background-HD-Image-13.jpg")
img4 = GradCam("http://style24x7.com/wp-content/uploads/2019/10/Baby-Turtle-Wallpapers-Background-HD-Image-12.jpg")
img5 = GradCam("https://wallpaperaccess.com/full/30909.jpg")
img6 = GradCam("http://getwallpapers.com/wallpaper/full/3/1/8/645044.jpg")
img7 = GradCam("https://www.availableideas.com/wp-content/uploads/2016/02/Animal-iPhone-wallpaper.jpg")
img8 = GradCam("http://getwallpapers.com/wallpaper/full/e/6/3/593404.jpg")
img9 = GradCam("http://www.hdnicewallpapers.com/Walls/Big/Dog/Cute_Dog_Animal_in_Garden_HD_Wallpapers.jpg")
img10 = GradCam("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0guKcT8Oe3GD9VSRYUpYzlrvme17hlM0Cad5fNzq4ARQ8bqGl&s")

img = [img1, img2, img3, img4, img5, img6, img7, img8, img9, img10]
# Out:
# 6
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 6
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)
# 2
# (?, 8, 8, 1024)
# (1024,)
# (8, 8, 1024)
# (8, 8)

# %%
for i in img: 
    cv2_imshow(i[0])
    cv2_imshow(i[1])
    print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863D30>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863CC0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F841A863EB8>
